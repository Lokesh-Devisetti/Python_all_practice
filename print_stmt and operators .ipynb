# %% [markdown]
# **Print statements**

# %% [markdown]
# - print "Hello World"
#     - print "Hello", <Variable Containing the String>
#     - print "Hello" + <Variable Containing the String>
#     - print "Hello %s" % <variable containing the string>

# %% [markdown]
# In Python, single, double and triple quotes are used to denote a string.
# Most use single quotes when declaring a single character.
# Double quotes when declaring a line and triple quotes when declaring a paragraph/multiple lines.

# %%
print("python")
# Out:
# python

# %%
print('manikanta')
# Out:
# manikanta

# %%
print("""Hello world""")
# Out:
# Hello world

# %%
age=23
print("my age is",age)
# Out:
# my age is 23

# %%
str1 = 'World'
print ('Hello',str1)

str2 = '!'
print ('Hello', str1, str2)
# Out:
# Hello World
# Hello World !

# %%
str1 = 'Data science'
str2 = 'Machine learning'
print("Python can do both "+str1+" and "+str2)
print("Python and "+str1)
# Out:
# Python can do both Data science and Machine learning
# Python and Data science

# %%
a='python'
print("welcome to the  class %s of Data science" %a)
# Out:
# welcome to the  class python of Data science

# %%
a = 10
# print("the value is = 1 ")
print("the value is = %d" %a)
# Out:
# the value is = 10

# %%
a = 'python'
b = "Data science"
c = "Aritficial intelligence"
d = "Machine learning"


print("%s is a programming language used to work on %s and %s is an heart for %s" %(a,b,d,b))
# Out:
# python is a programming language used to work on Data science and Machine learning is an heart for Data science

# %%
a = 1
b = 12.2
c = 'python'
print("the value of a is %d and value of b is %f and text of c is %s " %(a,b,c))
# Out:
# the value of a is 1 and value of b is 12.200000 and text of c is python

# %%
a = 1
b = 12.2
c = 'python'
print("the value of a is %d and value of b is %f and text of c is %s " %(a,c,b))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-ca1ea2abdaa3> in <cell line: 4>()
#       2 b = 12.2
#       3 c = 'python'
# ----> 4 print("the value of a is %d and value of b is %f and text of c is %s " %(a,c,b))
#
# TypeError: must be real number, not str

# %%
a = '1'
b = "12.2"
c = 'python'

print("the value of a is " , a , "the value of b is " , b , "The text of c is " , c)
print("the value of a is "+" "+ a+" the value of b is "+" "+b+" the text of c is "+c)
print("the value of a is %s and value of b is %s and text of c is %s " %(a,b,c))
# Out:
# the value of a is  1 the value of b is  12.2 The text of c is  python
# the value of a is  1 the value of b is  12.2 the text of c is python
# the value of a is 1 and value of b is 12.2 and text of c is python

# %%
print("my name is manikanta \n my age 23 \n i am living in india") #\n means we can write only one print statemnt and print no.of lines in output using \n
# Out:
# my name is manikanta
#  my age 23
#  i am living in india

# %%
a='manikanta'
b=23
c='india'
print(f"my name is {a} and my age is{b} i am living in {c}")
# Out:
# my name is manikanta and my age is23 i am living in india

# %%
course = 'data science'
fee = 15678
place = 'india'

# output = I am learning data science with 10.5 rupeers in india

print('I am learning '+course+' with '+str(fee)+' rupees in '+place)
# Out:
# I am learning data science with 15678 rupees in india

# %%
a=10
b=20
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a**b)
pow(2,5)
pow(2,5,3)
# Out:
# 30
# -10
# 200
# 0.5
# 0
# 100000000000000000000
# 2

# %%
10>20
# Out:
# False

# %%
10<20
# Out:
# True

# %%
10>=10
# Out:
# True

# %%
10<=20
# Out:
# True

# %%
import math

# %%
math.pow(2,5)
# Out:
# 32.0

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
math.factorial(5)
# Out:
# 120
