# %%
# tuple is an immutable -> you can't change anything
# tuple is represendted with -> () -> parenthesis:
# tuple accepts many data type : int , float , str

# %%
a=45
print(a)
# Out:
# 45

# %%
a=34,45,67
print(a)
print(type(a))
# Out:
# (34, 45, 67)
# <class 'tuple'>

# %%
a=(12,34.67,'manikanta')
print(a)
print(type(a))
# Out:
# (12, 34.67, 'manikanta')
# <class 'tuple'>

# %%
a=[10,23,45,34.55,78]
print(a[3])
# Out:
# 34.55

# %%
print(a[::-1])
# Out:
# [78, 34.55, 45, 23, 10]

# %%
print(a[::2])
# Out:
# [10, 45, 78]

# %%
a=(13,34,56,67.77,78)
a[5]=90
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-bc7b213ec3f2> in <cell line: 2>()
#       1 a=(13,34,56,67.77,78)
# ----> 2 a[5]=90
#       3 print(a)
#
# TypeError: 'tuple' object does not support item assignment

# %%
del a[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-734682c6a06c> in <cell line: 1>()
# ----> 1 del a[2]
#
# TypeError: 'tuple' object doesn't support item deletion

# %% [markdown]
# **tuple_build_in_functions**
#
# - `count : use to count the occurences`
# - `index : used to find the index`

# %%
a=(10,23,34,10,345)
print(a.count(10))
# Out:
# 2

# %%
print(a.index(10))
# Out:
# 0
